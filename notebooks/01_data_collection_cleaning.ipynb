# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# loading synthetic data
synthetic_csv = '../data/raw/synthetic_shipping_data.csv'
df = pd.read_csv(synthetic_csv)
df['date'] = pd.to_datetime(df["date"])
print("Synthetic dataset loaded:", df.shape)
df.head()

# check for missing values
print(df.isna().sum())

# fill missing values with column mean
df.fillna(df.mean(), inplace=True)

# Basic summary of statistics
print(df.describe())

# visualization check
plt.figure(figsize=(10,6))
sns.lineplot(data=df, x="date", y="freight_cost_index", label="Freight Cost Index")
sns.lineplot(data=df, x="date", y="oil_price_usd", label="Oil Price (USD)")
plt.title("Shipping Cost & Oil Price Over Time")
plt.xlabel("Date")
plt.ylabel("Value")
plt.legend()
plt.show()

plt.figure(figsize=(10,6))
sns.lineplot(data=df, x="date", y="port_congestion_index", label="Port Congestion")
sns.lineplot(data=df, x="date", y="consumer_demand_index", label="Consumer Demand Index")
plt.title("Port Congestion & Consumer Demand Over Time")
plt.xlabel("Date")
plt.ylabel("Index Value")
plt.legend()
plt.show()

df.to_csv("../data/processed/processed_shipping_data_clean.csv", index=False)
print("Cleaned dataset saved.")
# Out:
# Synthetic dataset loaded: (117, 5)
# date                     0
# freight_cost_index       0
# oil_price_usd            0
# port_congestion_index    0
# consumer_demand_index    0
# dtype: int64
#                                 date  freight_cost_index  oil_price_usd  \
# count                            117          117.000000     117.000000
# mean   2020-10-31 02:03:04.615384576         1787.490342      50.363846
# min              2016-01-01 00:00:00         1378.530000      13.110000
# 25%              2018-06-01 00:00:00         1644.200000      27.810000
# 50%              2020-11-01 00:00:00         1802.520000      52.370000
# 75%              2023-04-01 00:00:00         1912.850000      71.260000
# max              2025-09-01 00:00:00         2261.830000      85.440000
# std                              NaN          172.533966      21.459538
#
#        port_congestion_index  consumer_demand_index
# count             117.000000             117.000000
# ...
